# %%
from binary_demo import hello

# %%
hello()
# Out:
# 'Hello from binary-demo!'

# %%
from binary_demo._core import (
    hello_from_bin,
    binary_demo_hello,
    binary_demo_print_vector
)

# %%
hello_from_bin()
# Out:
# 'Hello from binary-demo!'

# %%
binary_demo_hello()
# Out:
# binary-demo/0.1.0: Hello World from binary_demo_hello!

# %%
binary_demo_print_vector(["a", "b", "c"])
# Out:
# binary_demo/0.1.0 a
# binary_demo/0.1.0 b
# binary_demo/0.1.0 c
