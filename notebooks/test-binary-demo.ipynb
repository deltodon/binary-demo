# %%
import binary_demo

# %%
binary_demo.__version__
# Out:
# '0.1.0'

# %%
help(binary_demo)
# Out:
# Help on package binary_demo:
#
# NAME
#     binary_demo
#
# DESCRIPTION
#     Pybind11 example plugin
#     -----------------------
#
#     .. currentmodule:: scikit_build_example
#
#     .. autosummary::
#       :toctree: _generate
#
#       hello_from_bin
#       add
#       subtract
#
# PACKAGE CONTENTS
#     _core
#
# FUNCTIONS
#     add(...) method of builtins.PyCapsule instance
#         add(arg0: int, arg1: int) -> int
#
#
#         Add two numbers
#
#         Some other explanation about the add function.
#
#     subtract(...) method of builtins.PyCapsule instance
#         subtract(arg0: int, arg1: int) -> int
#
#
#         Subtract two numbers
#
#         Some other explanation about the subtract function.
#
# DATA
#     __all__ = ['__doc__', '__version__', 'add', 'subtract']
#
# VERSION
#     0.1.0
#
# FILE
#     /home/deltodon/src/DELTODON/binary-demo/src/binary_demo/__init__.py

# %%
binary_demo.add(1, 2)
# Out:
# 3

# %%
binary_demo.subtract(9, 2)
# Out:
# 7

# %%
binary_demo.hello()
# Out:
# 'Hello from binary-demo!'

# %%
from binary_demo._core import hello_from_bin

# %%
hello_from_bin()
# Out:
# 'Hello from binary-demo!'
